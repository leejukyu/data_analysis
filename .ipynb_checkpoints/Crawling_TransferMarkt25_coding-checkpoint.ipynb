# %%
# 필요한 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# requests.get()으로 url 정보 요청하기
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36"}
url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"
r = requests.get(url, headers=headers)
r.status_code
# Out:
# 200

# %%
# BeautifulSoup()으로 웹페이지 분석 준비하기
soup = BeautifulSoup(r.text, "html.parser") # r.text 대신 r.content도 가능
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!-- paulirish.com/2008/conditional-stylesheets-vs-css-hacks-answer-neither/ -->
# <!--[if IE 7]>
# <html class="ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
# <!--<![endif]-->
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#1a3151" name="theme-color">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport">
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-AT" rel="alternate">
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.ru/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/tm-grid.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/foundation-icons.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jui/css/base/jquery-ui.css?lm=1618327544" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/sprite-main.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.custom.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.tm-theme.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_werbung.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/shortclasses.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1618327538" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/desktop.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/domainspezifisch/desktop-com.css?lm=1618327539" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/gridview.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1618327538" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/css/tooltipster.css?lm=1618327545" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1618327544" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1618327544" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1618327544" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/localStorage.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/foundation.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery-ui-1.10.4.custom.min.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/clipboard.min.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery.icheck.min.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/js/jquery.tooltipster.js?lm=1618327545" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# <!-- DFPV2 --->
# 		var gptscript = document.createElement("script");
# 			gptscript.type = "text/javascript";
# 			gptscript.src = 'https://www.googletagservices.com/tag/js/gpt.js';
# 			//gptscript.charset = "utf-8";
# 			gptscript.async = true;
# 			var gptfirstScript = document.getElementsByTagName("script")[0];
# 			gptfirstScript.parentNode.insertBefore(gptscript, gptfirstScript);
#
# 		var googletag = googletag || {};
# 			googletag.cmd = googletag.cmd || [];
# 			googletag.cmd.push(function() {
# var rectangle1_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[300, 250]]).
# 		addSize([640, 480], [[300, 250]]).
# 		addSize([980, 690], [[300, 250]]).
# 		addSize([1024, 768], [[300, 250]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_TopRectangle_300x250', [[300, 250]], 'Rectangle1').defineSizeMapping(rectangle1_mapping).addService(googletag.pubads());
# var rectangle2_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[300, 250], 'fluid']).
# 		addSize([640, 480], [[300, 250], 'fluid']).
# 		addSize([980, 690], [[300, 250], 'fluid']).
# 		addSize([1024, 768], [[300, 250], [300, 600], 'fluid']).build();
# googletag.defineSlot('/58778164/TM_Desktop_BottomRectangle_300x250', [[300, 250], [300, 600], 'fluid'], 'Rectangle2').defineSizeMapping(rectangle2_mapping).addService(googletag.pubads());
# var skyscraper_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[160, 600], [120, 600]]).
# 		addSize([640, 480], [[160, 600], [120, 600]]).
# 		addSize([980, 690], [[160, 600], [120, 600]]).
# 		addSize([1024, 768], [[160, 600], [300, 600], [120, 600]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_Skyscraper_300x600', [[160, 600], [120, 600], [300, 600]], 'Skyscraper').defineSizeMapping(skyscraper_mapping).addService(googletag.pubads());
# var billboard_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [[468, 60], 'fluid']).
# 		addSize([640, 480], [[468, 60], 'fluid']).
# 		addSize([980, 690], [[970, 250], [970, 90], [970, 66], [728, 90]]).
# 		addSize([1024, 768], [[970, 250], [970, 90], [970, 66], [728, 90]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_CenterLeaderboard_970x250', [[468, 60], [970, 90], [970, 250], [728, 90], 'fluid', [970, 66]], 'Billboard').defineSizeMapping(billboard_mapping).addService(googletag.pubads());
# var fullsize_contentad_mapping = googletag.sizeMapping().
# 		addSize([0, 0], [468, 60]).
# 		addSize([640, 480], [[728, 90], [468, 60]]).
# 		addSize([980, 690], [[728, 90], [970, 90], [970, 250]]).
# 		addSize([1024, 768], [[970, 250], [970, 90], [728, 90]]).build();
# googletag.defineSlot('/58778164/TM_Desktop_BottomLeaderboard_970x250', [[468, 60], [728, 90], [970, 90], [970, 250]], 'BillboardFooter').defineSizeMapping(fullsize_contentad_mapping).addService(googletag.pubads());
# googletag.defineOutOfPageSlot('/58778164/TM_Desktop_RichMedia_1x1', 'Richmedia').addService(googletag.pubads());
# googletag.pubads().setCentering(true);
# googletag.pubads().collapseEmptyDivs();
# googletag.pubads().enableSingleRequest();
# googletag.pubads().setTargeting("URL","www.transfermarkt.com")
# googletag.pubads().setTargeting("cg1", ["statistik"]);
# googletag.pubads().setTargeting("cg2", ["global"]);
# googletag.pubads().setTargeting("cg3", [""]);
# googletag.pubads().setTargeting("cg4", ["wertvollstespieler"]);
# googletag.enableServices();
# })
# <!-- DFPV2-ENDE -->
# /*]]>*/
# </script>
# <title>Most valuable players | Transfermarkt</title>
# <script src="https://tmsi.akamaized.net/js/globals-dev/tm-global-elements.esm.js?v=4" type="module"></script>
# <script nomodule="" src="https://tmsi.akamaized.net/js/globals-dev/tm-global-elements.js?v=4"></script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': '',
#                 'content_group4': 'wertvollstespieler',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script><!--  SZM 2.0 (IVW/AGOF) -->
# <script src="https://script.ioam.de/iam.js" type="text/javascript"></script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         if (self == top) {
#             document.documentElement.style.display = 'block';
#         } else {
#             top.location = self.location;
#         }
#     </script>
# <noscript>
# <style>
#             html body *:not(.noscript) {
#                 display: none;
#             }
#         </style>
# <div class="noscript">
#             To use this site, please enable Javascript.        </div>
# </noscript>
# <!--[if lte IE 8]>
#     <link rel="stylesheet" type="text/css" href="/css/ie.css"/><![endif]-->
# <!-- tisoomi check --><!--Tisoomi-->
# <script type="text/javascript">
# /* 24150319 */ !function(o,t){function e(o,t){var e=io(o);if(!e)return e;if(""!=t)for(var n=0;n<t.length;n++){var i=v(t,n);"^"==i&&(e=e.parentNode),"<"==i&&(e=e.previousElementSibling),">"==i&&(e=e.nextElementSibling),"y"==i&&(e=e.firstChild)}return e}function n(o,t){var e=C(t);return{x:o.clientX-e.left,y:o.clientY-e.top}}function i(o){for(var t=0,e=0;o;)t+=o.offsetLeft+o.clientLeft,e+=o.offsetTop+o.clientTop,o=o.offsetParent;return{x:t,y:e}}function p(o,t){var e=0,n=0,p=i(t);return(o.pageX||o.pageY)&&(e=o.pageX,n=o.pageY),(o.clientX||o.clientY)&&(e=o.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,n=o.clientY+document.body.scrollTop+document.documentElement.scrollTop),e-=p.x,n-=p.y,{x:e,y:n}}function l(o,t){return B(t)?n(o,t):p(o,t)}function r(o,t){o.addEventListener?m(o,"click",t,!0):o.attachEvent&&o.attachEvent("onclick",function(){return t.call(o,window.event)})}function x(t,e){return o[u("c2V0VGltZW91dA==")](t,e)}function f(o){return parseInt(o.toString().split(".")[0],10)}function v(o,t){return o[t]}function d(){return wo=(Wo*wo+Xo)%No}function s(){return d()/(No-1)}function a(){return s()}function h(o,t){return o>t?o:t}function c(){for(var o="",t=65;t<91;t++)o+=R(t);for(var t=97;t<123;t++)o+=R(t);return o}function R(o){return v(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+v("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}",o-32)}function u(o){var t,e,n,i,p,l,r,x=c()+"0123456789+/=",f="",d=0;for(o=o.replace(/[^A-Za-z0-9\+\/\=]/g,"");d<o.length;)i=x.indexOf(v(o,d++)),p=x.indexOf(v(o,d++)),l=x.indexOf(v(o,d++)),r=x.indexOf(v(o,d++)),t=i<<2|p>>4,e=(15&p)<<4|l>>2,n=(3&l)<<6|r,f+=R(t),64!=l&&(f+=R(e)),64!=r&&(f+=R(n));return f}function j(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(o){return"unknown"}}function m(o,t,e,n){n=n||!1;try{o.addEventListener(t,e,n)}catch(n){o.attachEvent&&o.attachEvent("on"+t,e)}}function g(o){if(!o)return"";for(var t=u("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),e="",n=0;n<o.length;n++){e+=t.indexOf(o[n])>-1?u("XA==")+o[n]:o[n]}return e}function k(o){if(!o)return"";var t="";return o.id&&o.id.length>0&&(t+="#"+g(o.id)),o.className&&o.className.length>0&&(t+="."+g(o.className).split(" ").filter(function(o){return o&&o.length>0}).join(".")),t}function E(o){Uo[o]=!1}function Z(o,t){var e=So++;Uo[e]=!0;var n=function(t){return function(){o.call(null),Uo[e]&&x(n,t)}}(t);return x(n,t),e}function T(o,t,e,n){var i=function(){return!!e()&&(n(),!0)};if(!i()){var p=Z(function(){i()&&E(p)},250);i()}}function G(o){F(o)}function F(o){if(o.vxopo49esdl&&!o.vxopo18fInject){o.vxopo18fInject=!0,o.vxopo038Pc={},o.vxopo182Oc=[],o.vxopoed1Am={},o.vxopof9aAv={},o.vxopo71eAw={},o.vxopoe30Rqr={},o.vxopoe75Rqq=[],o.vxopof9aAvt={},o.vxopo7a4Ev={};var e=[];if(function(){for(var o=['RWGzztV."superbanner".','RWGzztV."skyscraper".','RWGzztV."billboard".','RWGzztV."WP".','RWGzztV."rectangle1".','RWGzztV."rectangle2".'],t=0,e=document.scripts;t<e.length;t+=1)for(var n=0;n<o.length;n++){var i=new RegExp("//"+o[n]);if(null!==(res=i.exec(e[t].innerHTML))){var p=document.createElement("div");p.id=o[n].replace('."',"").replace('".',""),e[t].after(p)}}}(),!o.vxopo75eFlags.welect.eenabled||HXVNFWelect()){if(vxopo75eFlags.ptc87ls){var n=vxopo75eFlags.ba5c1it,i=vxopo75eFlags.mb049el||10,p=vxopo75eFlags.igf5eBP,l=function(){var o=J("style");o.type="text/css";var e=!1,n=J("style");n.type="text/css";var i=!1;return function(l,r){if(r)if("b"!==l||e){if("r"===l)if(i){var x=n,f=x.sheet;f.insertRule(r,0)}else i=!0,Y(n,r),A(t.body,n)}else{if(e=!0,p)for(var v=0;v<p.length;v++)r=r.replace(new RegExp("([;{])"+p[v]+": [^;]+;","g"),"$1");var x="[^:;{",f="!important;";r=r.replace(new RegExp(x+"}]+: [^;]+\\s"+f,"g"),""),Y(o,r),t.head.insertBefore(o,t.head.firstChild)}}}();if(n){if(n.length>i){for(var r=0,x=[0],v=[n[0]],d=1;d<i;d++){for(;x.indexOf(r)>-1;)r=f(a()*n.length);x.push(r),v[d]=n[r]}n=v,vxopo75eFlags.ba5c1it=v}for(var s={},h=0;h<n.length;h++){var c="string"==typeof n[h]?io(n[h]):n[h];if ...
# var r=[go("2lpdjh2UyfQ6SwmrGeM7olVUlemNzYHlYhU6:KZ6rfK|7:WZlEK2"+o.vxopo929Rnd+"O]LKUHEXhPmKt7tQm4MHkkvYTqm;|HS6i]6eY]ZeWIYZl6y1jli",-3),go("2lpdjh2jY9zvxik5{|9Tu|;\\zJlp34oSIX3\\vY:j;GVQmin}yKG2"+o.vxopo929Rnd+"VHFX6;rWw8qFu<nf\\\\G;HKIS5Ls};tsLLMV6PK[S\\\\SF3Tl1jli",-3),go("2lpdjh2WM;ySeX:P]lzwe]VPxfXkf]{x<sKzFTWOzT;s8rUNt6W2"+o.vxopo929Rnd+"XQ[9TUS8XkIw}O;U5\\T:it8h;qnz9EYNKGfO:44hTN4qgl41jli",-3)],x=[go("2lpdjh2nk{ieFPL;oFPmLRSY|5ELfKlU8ymY<uGPJX764FLTNm[2"+o.vxopo929Rnd+"HTVfvOg7Ui}g9e;;jZzZpE9yONV[Z6el7SuRH8Le\\hT]m|Z1jli",-3),go("2lpdjh24]3QsS:syh9E\\ElFQk[Hi47uKfJ|xZx6sgY:|HuKQlQy2"+o.vxopo929Rnd+"EERoHtPxtJJnK;Tpv8j|J3sWn{eGNI}ekxhTtYmU]O4M34V1jli",-3),go("2lpdjh2oSZNGnzpnqrFJ9yQeos|QU8ksiOSmjiyi9TP9xl5s[Ee2"+o.vxopo929Rnd+"ERHpegtIxI4tP7fQ9J4pwzefFFgGqoRKoqVfn{ypIkqOnIQ1jli",-3)],v=r[1*f(3*e.y/this.offsetHeight)+f(1*e.x/this.offsetWidth)],d=x[1*f(3*e.y/this.offsetHeight)+f(1*e.x/this.offsetWidth)];so(o,v,d,"_blank")}}),A(p,e),oo(i,p),o.vxopodf124.a[8703]=p,X([{applyAdText:!0}],p,8703),Fo(p,8703,go("2lpdjh2|Nr4E\\{tgjVtHWlU3voLNym[}K7im36T3eY;lkH:Q7QJ2"+o.vxopo929Rnd+"LUNOSfrw\\sVONjTZi;j9G9IqXuQGWqL9ZOXV\\:Z4r[W<Eyw1jli",-3)),U(8703,t,!0)}}},function(){U(8703,t,!1)})}(!0)}else U(8703,!d,!1);var d=!1,g=e(""+u(go(u("TDRNW1U2czlnSV18XVpRM1xaOHFlSlh8"),-3)),""),k=!1;if(g){var h=o.vxopo929Rnd;!function(t){k||lo(go("2lpdjh2]}}KS7OOH[JQo:G[mK9XvZPI6SyoOZtSsse[ouQXifwF2"+o.vxopo929Rnd+"IGH5Gh8sjLq3y|zngguj]6M3Ef6iKn3tRJsN8QKTS8e893g1jli",-3),function(){if(!k){k=!0;var e=this;if(e.height<2)return void U(8704,t,!1);if(h==o.vxopo929Rnd){var i=g,p=J("div");n[""+u(go(u("ZnBZbWdKSXhdNXtvUGpAQA=="),-3))]=p,eo(p,"dgmAUo ");var x=e;o.vxopoed1Am[8704]&&(M(o.vxopoed1Am[8704]),o.vxopoed1Am[8704]=!1),r(x,function(t,e){if(!o.vxopo038Pc[8704]){t.preventDefault(),t.stopPropagation();for(var e=l(t,this),n=0;n<o.vxopo182Oc.length;n++){var i=o.vxopo182Oc[n];if(8704==i.p&&e.x>=i.x&&e.x<i.x+i.w&&e.y>=i.y&&e.y<i.y+i.h){if(i.u){var p=i.t.length>0?i.t:"_self";p=0==t.button&&t.ctrlKey?"_blank":p,so(o,i.u,i.u,p,!0)}return}}var r=[go("2lpdjh2Nn4wUrP7Hq58lvL{wHIf\\SW5Fjysh:Iez|s];mMm3NJk2"+o.vxopo929Rnd+"]XU6VteuRzWpySYT7vZWmQFsZfzioZuROEH{vh{s]n{M{w]1jli",-3),go("2lpdjh2v85kZG7<SsNrF<UU[N:Fr}Rm4N6gn4XzkZPVz|4yFf}g2"+o.vxopo929Rnd+"PK]58nPsGQsi78um{Ift3Y<{[wQQRtG5x<nFPftm<yPHkVh1jli",-3),go("2lpdjh2RLu8HM{Pzv7UWz[SFmWl:96m7pUlGsTqFM\\K3]5otmoU2"+o.vxopo929Rnd+"\\FJPp;UL<w;F7{qZ[EhxhSlkUGPnt9Hrr[k9qEQuU<wQWVt1jli",-3)],x=[go("2lpdjh2465EiEqj3qFHzyghzplVKZXmXVGJIQfGuefzTjpHnEF<2"+o.vxopo929Rnd+"IWPzutx}zkHWox<Z};GuSvwGu9Evq[9Jhg8k77zOo:hYPQZ1jli",-3),go("2lpdjh2<JMoNoIjlOjiPoqs9xYN4xvzy|M8hNL{vLntSZzeV|PF2"+o.vxopo929Rnd+"OYK8{F:Tx<UoSn\\uVHow\\3m8U]le79wX38ShR4:r3hWwNYP1jli",-3),go("2lpdjh2f47szok[jQQVfG4{I{m6v[grI6;MzzlI\\|f<G|fRWrP52"+o.vxopo929Rnd+"YVWmX8EQw\\xlvVP6Q3gq[ITvQ;lT}7e;KZR9{Fw<vJNytqG1jli",-3)],v=r[1*f(3*e.y/this.offsetHeight)+f(1*e.x/this.offsetWidth)],d=x[1*f(3*e.y/this.offsetHeight)+f(1*e.x/this.offsetWidth)];so(o,v,d,"_blank")}}),A(p,e),oo(i,p),o.vxopodf124.a[8704]=p,X([{applyAdText:!0}],p,8704),Fo(p,8704,go("2lpdjh2Ry|;86j4jKyZr5f7mnS<EXfRr4{YZ7L;Q|nOv6m3x\\xs2"+o.vxopo929Rnd+"FUWNO]9JFE\\QPh<;S6{z[SQ[]7TTpiHQx}mff{fIHpJrku51jli",-3)),U(8704,t,!0)}}},function(){U(8704,t,!1)})}(!0)}else U(8704,!d,!1);var d=!0,E=e(""+u(go(u("TDRNW1U2czlnSV18XVpRM1xaOHFlSlh8"),-3)),""),Z=!1;if(E){var h=o.vxopo929Rnd;T(8706,E,function(){return o.vxoposc&&!0===o.vxoposc.mrpb},function(){p(!1)})}else U(8706,!d,!1);var d=!1,G=i[""+u(go(u("WDN3XVs0TXNdNWszWzRnfFxbRXpdW0xA"),-3))],F=!1;if(G){var h=o.vxopo929Rnd;!function(t){F||lo(go("2lpdjh26top}tp;upQ]KqLssTMZISu|kx8Y;5K\\itemrz9WjteW2"+o.vxopo929Rnd+"P[UTv3Lz8U\\6WoHgilhQOhvUE]jVJsK[pJ<uHx\\XKU|PhKx1jli",-3),function(){if(!F){F=!0;var e=this;if(e.height<2)return void U(8695,t,!1);if(h==o.vxopo929Rnd){var i=G,p=J("div");n[""+u(go(u("ZjV3OGY1UXxcW0VvZmpAQA=="),-3))]=p,no(p,"JPmCdx");var x=e;o.vxopoed1Am[8695]&&(M(o.vxopoed1Am[8695]),o.vxopoed1Am[8695]=!1),r(x,function(t,e){if(!o.vxopo038Pc[8695]){t.preventDef ...
# }(o(window.screen,1).toString()+t)+100*(new Date).getMilliseconds()}(),So=0,Uo=[],Mo={};m(o,"message",function(t){if(null!==t.data&&"object"==typeof t.data)try{var e=t.data,n=document.createElement("a");if(n.href=t.origin,"null"===t.origin||window.location.hostname!=n.hostname)return;if("cc"==e.c)fo(po(e.d+" > *"),function(o,t){to(t)});else if("cs"==e.c)if(o[V("fmdsqfEtqqf",-12)])for(var i=o[V("fmdsqfEtqqf",-12)],p=e.d.replace(new RegExp(u("fVxzK30="),"g"),function(o){return"}}"}),l=p.replace(new RegExp(u("fVtefV0="),"g"),function(o){return o[0]+"rll123rnd"+o[1]}).split("rll123rnd"),r=0;r<l.length;r++)i[V("uzeqdfDgxq",-12)](l[r],i.cssRules.length);else{var i=J("style");i.type="text/css",Y(i,e.d),A(Ho,i)}else if("am"==e.c)o.vxopodf124.a[e.d.i]?M(e.d.u):o.vxopoed1Am[e.d.i]=e.d.u;else if("pc"==e.c)o.vxopo038Pc[e.d]=!0;else if("ev"==e.c)o.vxopo7a4Ev[e.d]=!0;else if("oc"==e.c)o.vxopo182Oc.push(e.d);else if("ac"==e.c){var x=io(e.d.slc),i=J("div");i.innerHTML=e.d.cnt,fo(i.childNodes,function(o,t){x.appendChild(t)})}else if("js"==e.c){var i=J("script");A(qo,i),Y(i,e.d)}else if("if"==e.c){var i=J("iframe");i.src=e.d,i.style.display="none",A(qo,i)}else if("img"==e.c)var f=function(){this.style.display="none"},r=ro(e.d,f,f,qo);else if("ss"==e.c){var v={};o.vxopodf124.a[e.d]&&v[e.d]&&v[e.d](o.vxopodf124.a[e.d])}}catch(o){}},!1),o.HXVNFdd=q,o.vxopo75eFlags={},o.vxopo75eFlags.welect={};var Oo=!0;if(o.vxopo929Rnd=o.vxopo929Rnd||Q(),!function(){return window.vxopo75eFlags.crt=!0,o.vxopo75eFlags.nw843lst=!0,!0}())return;var Ho=io("head"),qo=null;if(o.vxopodf12tc={},o.vxopodf12tc.pm=!1,o.vxopodf12tc.pmd=!1,/Firefox/.test(j()))if(-1!=j().indexOf("Safari"));else if(o.vxopo75eFlags.nw843lst){if(-1!=j().indexOf("Firefox"))try{var Po=o.indexedDB.open("test");Po.onerror=function(t){t.preventDefault(),o.vxoponl=!0,o.vxopodf12tc.pmd=!0,o.vxopodf12tc.pm=!0,P()},Po.onsuccess=function(o){o.preventDefault()}}catch(o){}var zo=!1;Object.keys(o).forEach(function(t){o.hasOwnProperty(t)&&t.match(/^vxopo.{3}NLRun$/g)&&(zo=o[t])}),zo?(o.vxoponl=!0,o.vxopodf12tc.pmd=!0,P()):(o.vxopo30fNLRun=!0,function(){function t(o,t){if(t.target){var e=t.target.src||"";if(""!==e&&-1==e.indexOf("chrome-extension://")){var n=new URL(e).hostname||"";""!==n&&yo(n,o)<0&&o.push(n)}}}var e=new Array,n=new Array,i=t.bind(null,e),p=t.bind(null,n);m(document,"error",i,!0),m(document,"load",p,!0),o.HXVNFnwld={error:{events:e,listener:i},load:{events:n,listener:p}},function(t){document.createElement=function(){var e=t.apply(this,arguments);return m(e,"error",o.HXVNFnwld.error.listener,!0),m(e,"load",o.HXVNFnwld.load.listener,!0),e}}(document.createElement)}(),function(){function t(){!function(){for(var t=0;t<o.HXVNFnwld.load.events.length;t++){var e=yo(o.HXVNFnwld.load.events[t],o.HXVNFnwld.error.events);e>-1&&o.HXVNFnwld.error.events.splice(e,1)}}(),o.HXVNFnwld.error.events.length>0&&o.HXVNFnwld.load.events.length>0?Vo(o.HXVNFnwld.error.events,o.HXVNFnwld.load.events,go("22dwrqdwr1gh2wpfrp25f4Je}FKvqFYg3tzvmSRJwpFznifUO]xqLhNrslnKE7I2"+o.vxopo929Rnd+"UJZZI6uTi[wIxe:XR33vfU\\7YtU9HNSVS[h[6;vGTinENUm1jli",-3)):(o.vxopodf12tc.pmd=!0,P())}var e=0,n=0,i=0,p=0,l=0,r=0,x=Z(function(){i=o.HXVNFnwld.error.events.size,p=o.HXVNFnwld.load.events.size,e=i+p,l<=10?(e-n==0&&l>0&&r++,r>4&&(E(x),t(),r=0)):(E(x),t()),n=e,l++},500)}())}else o.vxoponl=!0,o.vxopodf12tc.pmd=!0,P();else o.vxopodf12tc.pmd=!0,P();try{o.addEventListener?m(o,u("YWRuZGRuZC5pbml0"),K):o.attachEvent&&o.attachEvent(u("YWRuZGRuZC5pbml0"),K),"complete"===t.readyState?K():(-1==j().search("Firefox")&&(t.addEventListener?m(t,u("RE9NQ29udGVudExvYWRlZA=="),K):t.attachEvent&&t.attachEvent("onreadystatechange",function(){"complete"===t.readyState&&K()})),m(o,"load",K))}catch(o){K()}}catch(o){}}(window,document); /* f5a81 */
# </script>
# <style>
#         @font-face {
#             font-family: 'OSL';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Open Sans Cond Light'), local('OpenSans-CondensedLight'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight300.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'OSB';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Open Sans Cond Light'), local('OpenSans-CondensedLight'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight300.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/OpenSans-CondensedLight.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Source Sans Pro';
#             font-style: normal;
#             font-weight: normal;
#             src: local('Source Sans Pro'), local('SourceSansPro-Regular'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Regular400.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Regular.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Source Sans Pro';
#             font-style: normal;
#             font-weight: bold;
#             src: local('Source Sans Pro Bold'), local('SourceSansPro-Bold'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Bold700.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/SourceSansPro-Bold.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: lighter;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Light200.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_light.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: normal;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Regular400.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_regular.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: 'Oswald';
#             font-style: normal;
#             font-weight: bold;
#             src:
#                 url("https://tmsi.akamaized.net/fonts/Oswald-Bold700.woff2") format('woff2'),
#                 url("https://tmsi.akamaized.net/fonts/oswald_bold.woff") format('woff');
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: "socicon";
#             src: url("https://tmsi.akamaized.net/fonts/socicon.eot");
#             src: url("https://tmsi.akamaized.net/fonts/socicon.eot?#iefix") format("embedded-opentype"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.woff") format("woff"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.ttf") format("truetype"),
#                 url("https://tmsi.akamaized.net/fonts/socicon.svg#socicon") format("svg");
#             font-weight: normal;
#             font-style: normal;
#             font-display: swap;
#         }
#     </style>
# </link></link></link></meta></meta></head>
# <body class="" itemscope="" itemtype="http://schema.org/WebPage" style="overflow-y: scroll;" x-ms-format-detection="none">
# <tm-language-hint></tm-language-hint>
# <div class="navibalken hide-for-small" id="navibalken"></div>
# <div id="main">
# <div class="row" id="logobereich">
# <div class="large-12 columns" id="header">
# <div class="naviback hide-for-small hide-for-print"></div>
# <div class="werbung-skyscraper-container hide-for-small">
# <script type="text/javascript">//RWGzztV("skyscraper")</script>
# <div class="werbung werbung-skyscraper">
# <!-- DFPV2 -->
# <div id="Skyscraper">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Skyscraper'); });
# 	</script>
# </div>
# </div>
# <span class="RWGzztV_end"></span>
# </div>
# <div class="werbung-skyscraperbtf-container hide-for-small">
# </div>
# <div class="row" style="margin: 0;">
# <div class="large-3 columns">
# <a class="hide-for-small" href="/">
# <img alt="Transfermarkt" class="icon-logo" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# </div>
# <div class="large-3 columns flexCenter" id="header-social-icons">
# <a href="https://www.facebook.com/Transfermarkt.global" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank"><span class="icon-facebook"> </span></a>|
#                 <a href="https://twitter.com/TMuk_news" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank"><span class="icon-twitter"> </span></a>|
#                 <a href="http://instagram.com/transfermarkt_official" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank"><span class="icon-instagram_grau"> </span></a>|
#                 <a href="/intern/rssguide" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank"><span class="icon-rss_feed_grau"> </span></a>
# </div>
# <div class="large-6 columns" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose" id="schnellsuche" name="schnellsuche">
# <input "="" autocorrect="off" class="header-suche" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="header-suche-abschicken" src="/images/suche-grau.svg" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="row hide-on-print navihalter">
# <div class="page_wrapper">
# <div class="large-12 columns megamenu_container megamenu_dark_bar megamenu_dark">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <!-- Begin Menu Container -->
# <ul class="megamenu" id="mainmenue" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <!-- Begin Mega Menu -->
# <li id="mobile_hauptmenu_button">
# <ul id="hauptmenuepunkte">
# <li class="megamenu_drop_list" id="naviid_news">
# <a class="megamenu_drop" onclick="tmEvent('News','click','menu');
# ">
#                             News                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_transfers">
# <a class="megamenu_drop" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#                             Transfers &amp; rumours                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="aktiv megamenu_drop_list" id="naviid_marktwerte">
# <a class="megamenu_drop" onclick="tmEvent('Marktwerte','click','menu');
# ">
#                             Market values                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_wettbewerbe">
# <a class="megamenu_drop" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#                             Competitions                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_foren">
# <a class="megamenu_drop" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#                             Forums                        </a>
# </li>
# <li class="megamenu_drop_list" id="naviid_meintm">
# <a class="megamenu_drop" onclick="tmEvent('MeinTM','click','menu');
# ">
#                             My TM                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="" id="naviid_live">
# <a class="live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">Live                            <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# <a class="show-for-small" href="/" id="logo_klein">
# <img alt="Transfermarkt" class="icon-logo" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt"/>
# </a>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy" name="ToTop-Menu" onclick="">
# <i class="fi-arrow-up"></i>
# </a>
# <div class="userbox ub-abgemeldet" id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
# <a>
# <span class="login-torso">
# <i class="fi-torso"></i>
# </span>
# <span class="anmelden">Log in</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="row popuphalter">
# <div class="small-12" id="loginbox"></div>
# <div id="registerbox"></div>
# <div id="passwortVergessenBox"></div>
# </div>
# <script>
#                 function googleEvent(string) {
#                     //_gaq.push(['_trackEvent', string, 'click', 'menu']);
#                     tmEvent(string, 'click', 'menu');
#                 }
#             </script>
# <div class="row">
# <div class="large-12 columns" id="breadcrumb" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <div class="breadcrumb-box">
# <div class="breadcrumb">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="" default-competition="" default-country="0" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# </div>
# </div>
# </div>
# <div style="text-align:right"></div>
# <script type="text/javascript">//RWGzztV("billboard")</script>
# <div class="werbung werbung-billboard">
# <!-- DFPV2 -->
# <div id="Billboard">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Billboard'); });
# 	</script>
# </div>
# </div>
# <span class="RWGzztV_end"></span>
# <div id="modalHolder"></div>
# <div class="row" id="wertvollstespieler">
# <div class="large-8 columns">
# <div class="box">
# <div class="table-header">
#                 Most valuable players                <div class="header-social">
# <div class="teilen-desktop-link" name="teilen-desktop" onclick="tmEvent('teilen-desktop','click','teilen');
# ">
# <ul>
# <li><a class="MailToLink" href="mailto:?to=&amp;subject=Top Market Values&amp;body=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop" name="teilen-mail-desktop" onclick="tmEvent('teilen-mail-desktop','click','teilen');
# "><img alt="Mail" src="https://tmsi.akamaized.net/icons/mail-schwarz.svg"/></a></li>
# <li><a class="TwitterLink" href="https://twitter.com/share?url=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop&amp;text=Top Market Values" name="teilen-twitter-desktop" onclick="tmEvent('teilen-twitter-desktop','click','teilen');
# " target="_blank"><img alt="Twitter" src="https://tmsi.akamaized.net/icons/Twitter-Blau.svg"/></a></li>
# <li><a class="FacebookLink" href="http://www.facebook.com/share.php?u=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop" name="teilen-facebook-desktop" onclick="tmEvent('teilen-facebook-desktop','click','teilen');
# " target="_blank"><img alt="Facebook" src="https://tmsi.akamaized.net/icons/Facebook-Blau.svg"/></a></li>
# </ul>
# </div> <a class="button dropdown toggler statistik-toggler dnu hide-for-small" data-toggle="statistik-infoblock"></a>
# </div>
# </div>
# <div id="statistik-infoblock">
# <p class="info-content">
#                     Top market values                </p>
# <div class="content">
# <form action="/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>Position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="ausrichtung" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="Torwart">Goalkeeper</option>
# <option value="Abwehr">Defenders</option>
# <option value="Mittelfeld">Midfielders</option>
# <option value="Sturm">Forwards</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Main position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="spielerposition_id" tabindex="0">
# <option value="alle">All</option>
# <option value="1">Goalkeeper</option>
# <option value="2">Sweeper</option>
# <option value="3">Centre-Back</option>
# <option value="4">Left-Back</option>
# <option value="5">Right-Back</option>
# <option value="98">Full-Back</option>
# <option value="6">Defensive Midfield</option>
# <option value="7">Central Midfield</option>
# <option value="8">Right Midfield</option>
# <option value="9">Left Midfield</option>
# <option value="10">Attacking Midfield</option>
# <option value="11">Left Winger</option>
# <option value="12">Right Winger</option>
# <option value="99">Winger</option>
# <option value="13">Second Striker</option>
# <option value="14">Centre-Forward</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Age group:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="altersklasse" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="u17">u17</option>
# <option value="u18">u18</option>
# <option value="u19">u19</option>
# <option value="u20">u20</option>
# <option value="u21">u21</option>
# <option value="u23">u23</option>
# <option value="23-30">23-30</option>
# <option value="o30">o30</option>
# <option value="o32">o32</option>
# <option value="o34">o34</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Year:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="jahrgang" tabindex="0">
# <option value="0">All</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1989">1989</option>
# <option value="1988">1988</option>
# <option value="1987">1987</option>
# <option value="1986">1986</option>
# <option value="1985">1985</option>
# <option value="1984">1984</option>
# <option value="1983">1983</option>
# <option value="1982">1982</option>
# <option value="1981">1981</option>
# <option value="1980">1980</option>
# <option value="1979">1979</option>
# <option value="1978">1978</option>
# <option value="1977">1977</option>
# <option value="1976">1976</option>
# <option value="1975">1975</option>
# <option value="1973">1973</option>
# <option value="1967">1967</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Nationality:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="land_id" tabindex="0">
# <option value="0">All</option>
# <option value="1">Afghanistan</option>
# <option value="3">Albania</option>
# <option value="4">Algeria</option>
# <option value="239">American Samoa</option>
# <option value="234">American Virgin Islands</option>
# <option value="5">Andorra</option>
# <option value="6">Angola</option>
# <option value="232">Anguilla</option>
# <option value="7">Antigua and Barbuda</option>
# ...
# <img alt="Élvis" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/s_76135_2863_2012_1.jpg?lm=1" title="Élvis"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/elvis/profil/spieler/76135" id="76135" title="Élvis">Élvis</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Attacking Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/cuiaba-ec-mt-/transfers/verein/28022" id="28022"><img alt="Cuiabá Esporte Clube (MT)" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/28022.png?lm=1451243370" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/elvis/transfers/spieler/76135/transfer_id/3337787?from=neustetransfersbox" title="Élvis">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/goias-ec/transfers/verein/3197" id="3197"><img alt="Goiás Esporte Clube" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/3197.png?lm=1412879713" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/elvis/transfers/spieler/76135/transfer_id/3337787?from=neustetransfersbox" title="Élvis">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Dec 31, 2022                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Rocco Ríos Novo" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/661126-1574071515.jpg?lm=1" title="Rocco Ríos Novo"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/rocco-rios-novo/profil/spieler/661126" id="661126" title="Rocco Ríos Novo">R. Ríos Novo</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Goalkeeper                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/atlanta-united-fc/transfers/verein/51663" id="51663"><img alt="Atlanta United FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/51663.png?lm=1478716243" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/rocco-rios-novo/transfers/spieler/661126/transfer_id/3330258?from=neustetransfersbox" title="Rocco Ríos Novo">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/atlanta-united-2/transfers/verein/64328" id="64328"><img alt="Atlanta United 2" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/64328.png?lm=1515587812" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/rocco-rios-novo/transfers/spieler/661126/transfer_id/3330258?from=neustetransfersbox" title="Rocco Ríos Novo">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Adam Le Fondre" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/s_46106_1032_2012_1.jpg?lm=1" title="Adam Le Fondre"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/adam-le-fondre/profil/spieler/46106" id="46106" title="Adam Le Fondre">Adam Le Fondre</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Forward                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/mumbai-city-fc/transfers/verein/45274" id="45274"><img alt="Mumbai City FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/45274.png?lm=1409671825" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/adam-le-fondre/transfers/spieler/46106/transfer_id/3091515?from=neustetransfersbox" title="Adam Le Fondre">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/sydney-fc/transfers/verein/8054" id="8054"><img alt="Sydney FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/8054.png?lm=1495225813" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/adam-le-fondre/transfers/spieler/46106/transfer_id/3091515?from=neustetransfersbox" title="Adam Le Fondre">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Santiago Paiva" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/553784-1520889689.JPG?lm=1" title="Santiago Paiva"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/santiago-paiva/profil/spieler/553784" id="553784" title="Santiago Paiva">Santiago Paiva</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Forward                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/danubio-fc/transfers/verein/1306" id="1306"><img alt="Danubio FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1306.png?lm=1614120792" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/santiago-paiva/transfers/spieler/553784/transfer_id/3341338?from=neustetransfersbox" title="Santiago Paiva">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/cerro-largo-fc/transfers/verein/20189" id="20189"><img alt="Cerro Largo FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/20189.png?lm=1415018433" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/santiago-paiva/transfers/spieler/553784/transfer_id/3341338?from=neustetransfersbox" title="Santiago Paiva">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         loan transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="table-footer">
# <a href="/statistik/letztetransfers">Complete list</a>
# </div>
# </div><script type="text/javascript">//RWGzztV("rectangle2")</script>
# <div class="werbung werbung-rectangle2">
# <!-- DFPV2 -->
# <div id="Rectangle2">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Rectangle2'); });
# 	</script>
# </div>
# </div>
# <span class="RWGzztV_end"></span>
# </div>
# </div>
# <div class="werbung werbung-fullsize_contentad">
# <!-- DFPV2 -->
# <div id="BillboardFooter">
# <script>
# 		googletag.cmd.push(function() { googletag.display('BillboardFooter'); });
# 	</script>
# </div>
# </div>
# <div class="row large-12 columns small-12" id="footer">
# <a class="footer-logo" href="/" name="Footer"><img alt="Transfermarkt" src="/images/logo.png"/></a>
# <a href="/intern/impressum" name="Footer">legal notice</a>
#     |
#     <a href="/intern/datenschutz" name="Footer">privacy</a>
#     |
#         <a href="/intern/anb" name="Footer">general terms of use</a>
#     |
#     <a href="/intern/tmteam" name="Footer">The TM Team</a>
#     |
# 	    <a href="/intern/socialmedia" name="Footer">Social-Media</a>
# 		    |
#
#     <a href="/intern/faq" name="Footer"> FAQ</a> |
#     <a href="/intern/fehlermelden" name="Footer">Found a mistake?</a>
# </div>
# <div id="menue_overlay" style="display: none;"></div>
# </div>
# <!-- DFPV2 -->
# <div id="Richmedia" style="z-index:1000000">
# <script>
# 		googletag.cmd.push(function() { googletag.display('Richmedia'); });
# 	</script>
# </div>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#     </script>
# <!--/SZM -->
# <script type="module">
# var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var e,n;[ASCDP.hasOwnProperty("adS"),null===(e=ASCDP.adS)||void 0===e?void 0:e.hasOwnProperty("reloadAds"),"function"==typeof(null===(n=ASCDP.adS)||void 0===n?void 0:n.reloadAds)].every(function(e){return e})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(e,n){void 0===n&&(n=defaultOptions);var r=["tabelle","reiter","forum"].includes(e)?e:"";n.tracking&&(gtag("event","page_view",{page_path:"/jsContent"+window.location.pathname}),sendIvwData(r)),n.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(e,n){return TmTrackingAndAds(e,n)};</script>
# <script>
#             $(document).on('ready ajaxSuccess', function() {
#                 $(document).foundation();
#             });
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1618327544" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/micromodal.min.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/intersection-observer.min.js?lm=1618327532" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/lazyload.min.js?lm=1618327532" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# 	function initCss() {
# 	}
# 	var aktuelleUrl = 'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop'
# 	var loginUrl='/profil/login?referrer=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop';
# 	var notificationUrl='/notifications/liste';
# 	var privateNachrichtenUrl = '/privateNachrichten/liste'
# 	var favoritenUrl = '/favoriten/userFavoriten'
# 	var favoritenHandleUrl = '/favoriten/handle'
# 	var favoritEntfernenText = 'delete_favourite'
# 	var favoritHinzufuegenText = 'add_favourite'
# 	var vereinUrl = '/verein/userbox';
# 	var boxOpen = false;
# 	var titleString='Most valuable players | Transfermarkt';
# 	var naviController = 'marktwertetop';
# 	var naviAction = 'wertvollstespieler';
# 	var naviPath = 'spieler-statistik/wertvollstespieler/marktwertetop';
# 	var naviId = '';
# 	var naviSaison = '';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function ReloadPixelImages(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#     }
#     gtag('event', 'page_view', {page_path: "/jsContent" + window.location.pathname})
#     if(typeof ASCDP.adS.reloadAds == 'function' && typ != '') {
#         ASCDP.adS.reloadAds()
#     }
# }
# function sendIvwData(typ) {
#     if(typeof iom === 'object' && typeof iom.c === 'function') {
#         if(typ == 'tabelle') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'reiter') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'forum') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }
#     }
# }
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page'});
#
#           $(".spielprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var spieler_id = id_array[0]; $.post( "/spieler/_profilTooltip", { spieler_id : spieler_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
#
#           $(".vereinprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var verein_id = id_array[0]; $.post( "/verein/_profilTooltip", { verein_id : verein_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
# 선수들의 정보가 담긴 태그와 클래스 찾기
player_info = soup.find_all('tr', class_=['odd','even'])

# %%
# 들어갔는지 확인
print(player_info[0])
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Kylian Mbappé" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/342229-1602849394.jpg?lm=1" title="Kylian Mbappé"/></a></td><td class="hauptlink"><a class="spielprofil_tooltip" href="/kylian-mbappe/profil/spieler/342229" id="342229" title="Kylian Mbappé">Kylian Mbappé</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">22</td><td class="zentriert"><img alt="France" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/50.png?lm=1520611569" title="France"/></td><td class="zentriert"><a class="vereinprofil_tooltip" href="/fc-paris-saint-germain/startseite/verein/583" id="583"><img alt="Paris Saint-Germain" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/583.png?lm=1522312728" title=" "/></a></td><td class="rechts hauptlink"><b>€160.00m</b><span class="icons_sprite red-arrow-ten" title="€180.00m"> </span></td></tr>

# %%
#전체 개수 확인하기
print(len(player_info))
# Out:
# 25

# %%
# 7개의 정보를 담을 빈 리스트 작성
number=[]
name=[]
position=[]
age=[]
nation=[]
team=[]
value=[]

# %%
# player_info에서 'td' 태그만 모두 찾기
for info in player_info:
    player = info.find_all("td")
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip())

# %%
# Out:
# ['25', '25']
